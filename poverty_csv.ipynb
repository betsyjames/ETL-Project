# %%
import pandas as pd
from splinter import Browser
from webdriver_manager.chrome import ChromeDriverManager
import requests


file_to_load = "Resources/poverty_csv_df.csv"

poverty_csv_df = pd.read_csv(file_to_load)
poverty_csv_df

# poverty_csv_db.drop("District of Columbia", axis = 0, inplace = True)
# Out:
#     Index                 State     Number Lower_Bound_90CI Upper_Bound_90CI
# 0       1               Alabama    747,478          730,491          764,465
# 1       2                Alaska     73,033           68,640           77,426
# 2       3               Arizona    963,007          940,142          985,872
# 3       4              Arkansas    468,575          456,478          480,672
# 4       5            California  4,560,419        4,509,811        4,611,027
# 5       6              Colorado    531,331          516,240          546,422
# 6       7           Connecticut    343,101          331,999          354,203
# 7       8              Delaware    106,227          100,509          111,945
# 8       9  District of Columbia     94,985           88,692          101,278
# 9      10               Florida  2,681,832        2,641,009        2,722,655
# 10     11               Georgia  1,397,607        1,370,705        1,424,509
# ...

# %%
poverty_csv_df.drop(27, axis = 0, inplace = True)
poverty_csv_df
# Out:
#                    State     Number Lower_Bound_90CI Upper_Bound_90CI
# 0                Alabama    747,478          730,491          764,465
# 1                 Alaska     73,033           68,640           77,426
# 2                Arizona    963,007          940,142          985,872
# 3               Arkansas    468,575          456,478          480,672
# 4             California  4,560,419        4,509,811        4,611,027
# 5               Colorado    531,331          516,240          546,422
# 6            Connecticut    343,101          331,999          354,203
# 7               Delaware    106,227          100,509          111,945
# 8   District of Columbia     94,985           88,692          101,278
# 9                Florida  2,681,832        2,641,009        2,722,655
# 10               Georgia  1,397,607        1,370,705        1,424,509
# 11                Hawaii    124,650          118,029          131,271
# ...

# %%
poverty_csv_df.to_csv(r'poverty_csv_df.csv')
